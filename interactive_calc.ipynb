# %%
from debt_calculator import parse_csv

csv_file = "debts/tristan_loans.csv"

all_loans = parse_csv(csv_file)
monthly_payment = 2000

all_loans.calculate_loans(1000, monthly_payment, showplots="all")
# Out:
# For Tristan, starting loan total = $102722.21. Paying $2000 per month will
# result in achieving a balance of $0.00 after 59 months (4.9 years).
# This resulted in paying a total of $116977.50, which means we paid $14255.29 in interest.

# %%
from ipywidgets import interact, IntSlider, HBox, Layout
from debt_calculator import parse_csv

csv_file = "debts/emily_loans.csv"

def interactive_loan_visualizer(monthly_payment):
    all_loans = parse_csv(csv_file)
    all_loans.calculate_loans(1000, monthly_payment, showplots="all")

slider = IntSlider(value=4000, min=500, max=10000, step=100, description="Monthly Payment", layout=Layout(width='600px'), style={'description_width': '150px'})

interact(interactive_loan_visualizer, monthly_payment=slider)
